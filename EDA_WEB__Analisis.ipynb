# %% [markdown]
# <a href="https://colab.research.google.com/github/EDUTORRESA21/Python_analisis/blob/main/EDA_WEB__Analisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA: PAGINA WEB

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/content/drive/MyDrive/1 Bootcamp_Python_DSRP/8_Octava_Clase/web_1.xlsx")

df.head(5)
# Out:
#          dia  Visitas de la Página  Tiempo promedio en la página (segundos)  \
# 0 2018-01-01                  3328                                       71
# 1 2018-02-01                  3097                                       56
# 2 2018-03-01                  3202                                       79
# 3 2018-04-01                  3170                                       81
# 4 2018-05-01                  2366                                       50
#
#    Clicks
# 0      13
# 1       7
# 2       5
# 3       3
# 4       3

# %%
#Cambiar de nombre las columnas:
df = df.rename(columns={'dia':'Fecha'})
df = df.rename(columns={'Visitas de la Página':'visita_pagina'})
df = df.rename(columns={'Tiempo promedio en la página (segundos)':'tiempo_seg'})

# %%
#df.head(5)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Fecha          66 non-null     datetime64[ns]
#  1   visita_pagina  66 non-null     int64
#  2   tiempo_seg     66 non-null     int64
#  3   Clicks         66 non-null     int64
#  4   año            66 non-null     int64
#  5   mes            66 non-null     int64
#  6   mes_nombre     66 non-null     object
#  7   dia            66 non-null     int64
# dtypes: datetime64[ns](1), int64(6), object(1)
# memory usage: 4.2+ KB

# %%
df['año'] = df['Fecha'].dt.year
df['mes'] = df['Fecha'].dt.month
df['mes_nombre'] = df['Fecha'].dt.month_name()
df['dia'] = df['Fecha'].dt.day

# %%
df.head(5)
# Out:
#        Fecha  visita_pagina  tiempo_seg  Clicks   año  mes mes_nombre  dia
# 0 2018-01-01           3328          71      13  2018    1    January    1
# 1 2018-02-01           3097          56       7  2018    2   February    1
# 2 2018-03-01           3202          79       5  2018    3      March    1
# 3 2018-04-01           3170          81       3  2018    4      April    1
# 4 2018-05-01           2366          50       3  2018    5        May    1

# %%
df.isnull().sum()
# Out:
# Fecha            0
# visita_pagina    0
# tiempo_seg       0
# Clicks           0
# año              0
# mes              0
# mes_nombre       0
# dia              0
# dtype: int64

# %%
df_filtered = df[df['año'].isin([2021,2022])]

df_filtered.tail(5)
# Out:
#         Fecha  visita_pagina  tiempo_seg  Clicks   año  mes mes_nombre  dia
# 55 2022-08-01           2068          73       6  2022    8     August    1
# 56 2022-09-01           1739          77       2  2022    9  September    1
# 57 2022-10-01           1764          73       6  2022   10    October    1
# 58 2022-11-01           1741          81       7  2022   11   November    1
# 59 2022-12-01           2074          65      11  2022   12   December    1

# %%
sns.histplot(
    data=df_filtered['visita_pagina'],
    bins=10,
    kde=False
)
plt.show()

# %%
sns.histplot(
    data=df_filtered['tiempo_seg'],
    bins=10,
    kde=False
)
plt.show()

# %%
sns.histplot(
    data=df_filtered['Clicks'],
    bins=10,
    kde=False
)
plt.show()

# %%
sns.scatterplot(data=df_filtered, x='visita_pagina', y='tiempo_seg')
plt.title('visita_pagina vs tiempo_seg')
plt.xlabel('Visitas a la Página')
plt.ylabel('Tiempo Promedio en Segundos')
plt.show()

# %%
sns.scatterplot(data=df_filtered, x='tiempo_seg', y='Clicks')
plt.title('tiempo_seg vs Clicks')
plt.xlabel('Tiempo Promedio en Segundos')
plt.ylabel('Clicks')
plt.show()

# %% [markdown]
# #PARTE 2

# %%
df2 = pd.read_excel("/content/drive/MyDrive/1 Bootcamp_Python_DSRP/8_Octava_Clase/web_2.xlsx")

df2.head(5)
# Out:
#          dia    Ingresos       Gasto  Margen  Rentabilidad
# 0 2018-01-01  480728.006  362044.206     NaN           NaN
# 1 2018-02-01  641155.476  371550.776     NaN           NaN
# 2 2018-03-01  890076.650  614858.550     NaN           NaN
# 3 2018-04-01  552673.978  348520.978     NaN           NaN
# 4 2018-05-01  750776.984  494685.584     NaN           NaN

# %%
#Sacando el margen y la rentabilidad:
df2['Margen'] =df2['Ingresos']- df2['Gasto']
df2['Rentabilidad'] =(df2['Margen']/ df2['Gasto'])*100

df2.head(5)
# Out:
#          dia    Ingresos       Gasto    Margen  Rentabilidad
# 0 2018-01-01  480728.006  362044.206  118683.8     32.781577
# 1 2018-02-01  641155.476  371550.776  269604.7     72.562007
# 2 2018-03-01  890076.650  614858.550  275218.1     44.761206
# 3 2018-04-01  552673.978  348520.978  204153.0     58.576962
# 4 2018-05-01  750776.984  494685.584  256091.4     51.768519

# %%
df2 = df2.rename(columns={'dia':'Fecha'})

df2['año'] = df2['Fecha'].dt.year
df2['mes'] = df2['Fecha'].dt.month
df2['mes_nombre'] = df2['Fecha'].dt.month_name()
df2['dia'] = df2['Fecha'].dt.day

# %%
df2.head(5)
# Out:
#        Fecha    Ingresos       Gasto    Margen  Rentabilidad   año  mes  \
# 0 2018-01-01  480728.006  362044.206  118683.8     32.781577  2018    1
# 1 2018-02-01  641155.476  371550.776  269604.7     72.562007  2018    2
# 2 2018-03-01  890076.650  614858.550  275218.1     44.761206  2018    3
# 3 2018-04-01  552673.978  348520.978  204153.0     58.576962  2018    4
# 4 2018-05-01  750776.984  494685.584  256091.4     51.768519  2018    5
#
#   mes_nombre  Fecha
# 0    January      1
# 1   February      1
# 2      March      1
# 3      April      1
# 4        May      1

# %%
#Margen por año:

df2_filtered = df2[df2['año'].isin([2021,2022])]

df2_filtered.tail(4)
# Out:
#         Fecha    Ingresos       Gasto    Margen  Rentabilidad   año  mes  \
# 56 2022-09-01  419302.314  318983.614  100318.7     31.449484  2022    9
# 57 2022-10-01  191171.579  144265.179   46906.4     32.514014  2022   10
# 58 2022-11-01  133966.902  101141.602   32825.3     32.454795  2022   11
# 59 2022-12-01  615712.783  449145.083  166567.7     37.085500  2022   12
#
#    mes_nombre  Fecha
# 56  September      1
# 57    October      1
# 58   November      1
# 59   December      1

# %%
#Margen
margen = df2_filtered.groupby('año')['Margen'].sum()
print(margen)
# Out:
# año
# 2021    1695433.8
# 2022    1190302.6
# Name: Margen, dtype: float64

# %%
#Rentabilidad
rent = df2_filtered.groupby('año')['Rentabilidad'].mean()

rent
# Out:
# año
# 2021    45.043166
# 2022    40.507771
# Name: Rentabilidad, dtype: float64

# %%
df3_f = df2[df2['año'].isin([2023])]

df3_f.head(5)
df3_f.tail(5)
# Out:
#         Fecha    Ingresos       Gasto    Margen  Rentabilidad   año  mes  \
# 61 2023-02-01  573918.453  386219.753  187698.7     48.598938  2023    2
# 62 2023-03-01  397550.100  272909.500  124640.6     45.671037  2023    3
# 63 2023-04-01  282044.858  206488.358   75556.5     36.591167  2023    4
# 64 2023-05-01  310116.006  227344.706   82771.3     36.407841  2023    5
# 65 2023-06-01  615950.171  409508.971  206441.2     50.411887  2023    6
#
#    mes_nombre  Fecha
# 61   February      1
# 62      March      1
# 63      April      1
# 64        May      1
# 65       June      1

# %%
df3_f.groupby('año')['Margen'].sum()
# Out:
# año
# 2023    798464.5
# Name: Margen, dtype: float64

# %%
df3_f.groupby('año')['Rentabilidad'].mean()
# Out:
# año
# 2023    44.754395
# Name: Rentabilidad, dtype: float64

# %%
#Solo quiero ver

margen_mes = df2.groupby([(df2['año']=='2022'), 'mes'])['Margen'].sum()

margen_mes
# Out:
# año    mes
# False  1       906628.7
#        2      1049163.5
#        3       927353.4
#        4       928577.4
#        5       859571.0
#        6       970825.8
#        7       656557.0
#        8       806614.3
#        9       751039.6
#        10      717003.9
#        11      709328.4
#        12      676627.2
# Name: Margen, dtype: float64
